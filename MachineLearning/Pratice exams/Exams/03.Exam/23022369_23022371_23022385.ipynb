# %% [markdown]
# # Aula assíncrona 15 - Desempenhodos Algoritmos FeatEng

# %% [markdown]
# RA: 23022369 - Bruno Caboclo Dos Santos Ribeiro<br>
# RA: 23022371 - Carlos Eduardo de Souza<br>
# RA: 23022385 - Julia Correa Colombo

# %% [markdown]
# ### Importando bibliotecas

# %%
import pandas as pd
import pandas as pd
import numpy as np
import torch
import torchvision
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import torch
#       5 import torchvision
#
# ModuleNotFoundError: No module named 'torch'

# %%
# Carregar o conjunto de dados proposto no canvas(Arquivo BestSongsOnSpotifyFrom2000-2023-1.csv)
print('\033[33m\nImportando arquivo...\033[m')
dataFrame = pd.read_csv('BestSongsOnSpotifyFrom2000-2023.csv', delimiter=';')
dataFrame.head()

print('\033[33mExibindo DataFrame...\033[m')
dataFrame
# Out:
# Importando arquivo...
# Exibindo DataFrame...
#                                        title               artist  \
# 0                                    Flowers          Miley Cyrus
# 1                          Cupid - Twin Ver.          FIFTY FIFTY
# 2                                       BESO              ROSALÍA
# 3                         Boy's a liar Pt. 2       PinkPantheress
# 4     Creepin' (with The Weeknd & 21 Savage)         Metro Boomin
# ...                                      ...                  ...
# 2380                              Southbound           Beach Blvd
# 2381     Dance with Somebody - Radio Version           Mando Diao
# 2382                                    Flow      Desire Machines
# 2383                      Scared of the Dark  Everything Brighter
# 2384                                   Sorry                LEADR
#
#              top genre  year  bpm  energy  danceability   dB  liveness  \
# ...
